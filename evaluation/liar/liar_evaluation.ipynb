# %%
from agents.agent_api import create_chatbot, get_response
from evaluation.liar.liar_loader import LiarLoader

liar_dataset = LiarLoader()
chatbot = create_chatbot("OpenAI", schema=None)
get_response(chatbot, "Novak Djokovic is the best tennis player in the world.")
# Out:
# 'Unclear\n\n"Best" is subjective and depends on criteria (current ranking, Grand Slam titles, head-to-head records, recent form). Rankings and performance also change over time, and no specific timeframe is given. While Djokovic holds many records and has often been ranked No. 1, calling him "the best" without defined criteria isn’t a verifiable factual claim.'
