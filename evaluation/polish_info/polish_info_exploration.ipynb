# %%
import pandas as pd
import json

# %%
with open("../data/polish_info/data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)
df

# %%
df["label"].value_counts()

# %%
df.sample(10)

# %%
print(f"Total statements: {len(df)}")
print(f"\nLabel distribution:")
print(df["label"].value_counts())
print(f"\nAverage statement length: {df['statement'].str.len().mean():.2f} characters")

# %%
# Load using the custom loader
from evaluation.polish_info.polish_info_loader import PolishInfoLoader

loader = PolishInfoLoader(n=50, split="train")
print(f"Loaded {len(loader)} samples")

# %%
# Test getting an item
statement, label = loader[0]
print(f"Statement: {statement}")
print(f"Label: {label}")
