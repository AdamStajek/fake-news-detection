# %%
import os
from pathlib import Path

import pandas as pd

# %%
BASE_PATH = Path(os.path.abspath("")) / "evaluation" / "data" / "mmcovid"
ENGLISH_NEWS_PATH = BASE_PATH / "english_news.csv"
NEWS_COLLECTION_PATH = BASE_PATH / "news_collection.json"
DEHYDRATE_USER_PROFILE_PATH = BASE_PATH / "dehydrate_user_profile.json"
DEHYDRATE_TWEET_COLLECTION_PATH = BASE_PATH / "dehydrate_tweet_collection.json"
NEWS_TWEET_RELATION_PATH = BASE_PATH / "news_tweet_relation.json"
TWEET_TWEET_RELATION_PATH = BASE_PATH / "tweet_tweet_relation.json"

# %%
english_news = pd.read_csv(ENGLISH_NEWS_PATH)

# %%
english_news
# Out:
#                           news_id agency  \
# 0                webMD-2102578004  webMD
# 1                webMD-3451925886  webMD
# 2                webMD-9632391802  webMD
# 3                webMD-2255331138  webMD
# 4                webMD-3472860572  webMD
# ...                           ...    ...
# 7418  twitter-1232691481430892545    NaN
# 7419  twitter-1231981159330066434    NaN
# 7420  twitter-1231866685046566912    NaN
# 7421  twitter-1231855642824134656    NaN
# 7422  twitter-1230175903738716160    NaN
#
#                                                   claim  \
# 0     Coronavirus Is a Breeding Ground for Conspirac...
# 1                 COVID-19 and PPE: Some of Us Will Die
# 2     Worldwide Number of COVID-19 Cases Over 1 Million
# 3                              COVID-19 Likely Seasonal
# 4                Mobile Apps for Coronavirus (COVID-19)
# ...                                                 ...
# 7418                                                NaN
# 7419                                                NaN
# 7420                                                NaN
# 7421                                                NaN
# 7422                                                NaN
#
#                                                fact_url label lang  \
# 0     https://www.snopes.com/news/2020/02/28/coronav...  real   en
# 1     https://www.webmd.com/lung/news/20200320/covid...  real   en
# 2     https://www.webmd.com/lung/news/20200403/world...  real   en
# 3     https://www.webmd.com/lung/news/20200326/covid...  real   en
# 4           https://www.webmd.com/lung/coronavirus-apps  real   en
# ...                                                 ...   ...  ...
# 7418                                                NaN  real   en
# 7419                                                NaN  real   en
# 7420                                                NaN  real   en
# 7421                                                NaN  real   en
# 7422                                                NaN  real   en
#
#                                              ref_source  \
# 0     {"_id":{"$oid":"5f338e26dfd2b7a505e3d5c9"},"id...
# 1     {"_id":{"$oid":"5f338e28dfd2b7a505e3d5d2"},"id...
# 2     {"_id":{"$oid":"5f338e4bdfd2b7a505e3d635"},"id...
# 3     {"_id":{"$oid":"5f338e4ddfd2b7a505e3d63d"},"id...
# 4     {"_id":{"$oid":"5f338e62dfd2b7a505e3d67f"},"id...
# ...                                                 ...
# 7418  {"text":"Commissioner @SKyriakidesEU met the I...
# 7419  {"text":"We are working on all fronts to suppo...
# 7420  {"text":"We are working around the clock to su...
# 7421  {"text":"Statement on the EU’s response, prepa...
# 7422  {"text":"The outbreak of #COVID19 epidemic: \n...
#
#                                          ref_source_url  \
# 0     https://www.snopes.com/news/2020/02/28/coronav...
# 1     https://www.webmd.com/lung/news/20200320/covid...
# 2     https://www.webmd.com/lung/news/20200403/world...
# 3     https://www.webmd.com/lung/news/20200326/covid...
# 4           https://www.webmd.com/lung/coronavirus-apps
# ...                                                 ...
# 7418  https://twitter.com/i/web/status/1232691481430...
# 7419  https://twitter.com/i/web/status/1231981159330...
# 7420  https://twitter.com/i/web/status/1231866685046...
# 7421  https://twitter.com/i/web/status/1231855642824...
# 7422  https://twitter.com/i/web/status/1230175903738...
#
#                                               statement
# 0     Coronavirus Is a Breeding Ground for Conspirac...
# 1                   COVID19 and PPE Some of Us Will Die
# 2      Worldwide Number of COVID19 Cases Over 1 Million
# 3                               COVID19 Likely Seasonal
# 4                   Mobile Apps for Coronavirus COVID19
# ...                                                 ...
# 7418  Commissioner @SKyriakidesEU met the Italian Mi...
# 7419  We are working on all fronts to support effort...
# 7420  We are working around the clock to support EU ...
# 7421  Statement on the EU’s response, preparedness a...
# 7422  The outbreak of #COVID19 epidemic: \nThe EU is...
#
# [7423 rows x 9 columns]

# %%
english_news[950:1200]["claim"]
# Out:
# 950     Georgia Gov. Brian Kemp “mandates restaurants ...
# 951      Dr. Elisa Granato, one of the first volunteer...
# 952     Harvard professor Charles Lieber was arrested ...
# 953     French health care workers are putting on defe...
# 954     Young people “have a greater chance of being k...
#                               ...
# 1195    U.S. Vice President Mike Pence delivered empty...
# 1196    Ventura County public health director say that...
# 1197    President Trump sent out a tweet that included...
# 1198     A card claiming to exempt the holder from wea...
# 1199     Multiple Facebook posts shared tens of thousa...
# Name: claim, Length: 250, dtype: object
